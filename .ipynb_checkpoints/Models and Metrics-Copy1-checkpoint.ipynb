# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %config InlineBackend.figure_formats = ['svg']
# %matplotlib inline

import statsmodels.api as sm
from sklearn.linear_model import LogisticRegressionCV
from sklearn.metrics import roc_auc_score, confusion_matrix, roc_curve
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import precision_score, recall_score, precision_recall_curve,f1_score, fbeta_score

# %% [markdown]
# <br>

# %% [markdown]
# ### Import Data and Create Binary Target

# %%
fires = pd.read_csv('Fires_During_After_2000.csv')
# Out:
# /Users/madelinevossbrinck/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (7,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
fires['FIRE_SIZE_CLASS_BIN'] = np.where(fires['FIRE_SIZE']> 1, 1, 0)
fires['FIRE_SIZE_CLASS_BIN'].value_counts()
# Out:
# 0    799119
# 1    509198
# Name: FIRE_SIZE_CLASS_BIN, dtype: int64

# %% [markdown]
# <br>

# %% [markdown]
# ### Train Test Split and Dummy Variable Creation

# %%
from sklearn.model_selection import train_test_split

fires_train, fires_test = train_test_split(fires, test_size=0.2, random_state=42)

# %%
combined_df = pd.get_dummies(fires_train, columns = ['STAT_CAUSE_DESCR', 'REGION'])
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1046653 entries, 1081941 to 121958
# Data columns (total 54 columns):
#  #   Column                              Non-Null Count    Dtype
# ---  ------                              --------------    -----
#  0   Unnamed: 0                          1046653 non-null  int64
#  1   OBJECTID                            1046653 non-null  int64
#  2   SOURCE_SYSTEM_TYPE                  1046653 non-null  object
#  3   SOURCE_SYSTEM                       1046653 non-null  object
#  4   NWCG_REPORTING_AGENCY               1046653 non-null  object
#  5   NWCG_REPORTING_UNIT_ID              1046653 non-null  object
#  6   NWCG_REPORTING_UNIT_NAME            1046653 non-null  object
#  7   SOURCE_REPORTING_UNIT               1046653 non-null  object
#  8   SOURCE_REPORTING_UNIT_NAME          1046653 non-null  object
#  9   FIRE_NAME                           561210 non-null   object
#  10  FIRE_YEAR                           1046653 non-null  int64
#  11  DISCOVERY_DATE                      1046653 non-null  float64
#  12  DISCOVERY_DOY                       1046653 non-null  int64
#  13  DISCOVERY_TIME                      562562 non-null   float64
#  14  STAT_CAUSE_CODE                     1046653 non-null  float64
#  15  CONT_DATE                           542894 non-null   float64
#  16  CONT_DOY                            542894 non-null   float64
#  17  CONT_TIME                           501466 non-null   float64
#  18  FIRE_SIZE                           1046653 non-null  float64
#  19  FIRE_SIZE_CLASS                     1046653 non-null  object
#  20  LATITUDE                            1046653 non-null  float64
#  21  LONGITUDE                           1046653 non-null  float64
#  22  OWNER_CODE                          1046653 non-null  float64
#  23  OWNER_DESCR                         1046653 non-null  object
#  24  STATE                               1046653 non-null  object
#  25  Shape                               1046653 non-null  object
#  26  DAYS_TO_CONTAIN                     1046653 non-null  float64
#  27  DISCOVERY_DATE_DT                   1046653 non-null  object
#  28  CONT_DATE_DT                        542894 non-null   object
#  29  FIRE_SIZE_CLASS_BIN                 1046653 non-null  int64
#  30  STAT_CAUSE_DESCR_Arson              1046653 non-null  uint8
#  31  STAT_CAUSE_DESCR_Campfire           1046653 non-null  uint8
#  32  STAT_CAUSE_DESCR_Children           1046653 non-null  uint8
#  33  STAT_CAUSE_DESCR_Debris Burning     1046653 non-null  uint8
#  34  STAT_CAUSE_DESCR_Equipment Use      1046653 non-null  uint8
#  35  STAT_CAUSE_DESCR_Fireworks          1046653 non-null  uint8
#  36  STAT_CAUSE_DESCR_Lightning          1046653 non-null  uint8
#  37  STAT_CAUSE_DESCR_Miscellaneous      1046653 non-null  uint8
#  38  STAT_CAUSE_DESCR_Missing/Undefined  1046653 non-null  uint8
#  39  STAT_CAUSE_DESCR_Powerline          1046653 non-null  uint8
#  40  STAT_CAUSE_DESCR_Railroad           1046653 non-null  uint8
#  41  STAT_CAUSE_DESCR_Smoking            1046653 non-null  uint8
#  42  STAT_CAUSE_DESCR_Structure          1046653 non-null  uint8
#  43  REGION_Alaska                       1046653 non-null  uint8
#  44  REGION_Northeast                    1046653 non-null  uint8
#  45  REGION_Northern Rockies             1046653 non-null  uint8
#  46  REGION_Northwest                    1046653 non-null  uint8
#  47  REGION_Ohio Valley                  1046653 non-null  uint8
#  48  REGION_Other                        1046653 non-null  uint8
#  49  REGION_South                        1046653 non-null  uint8
#  50  REGION_Southeast                    1046653 non-null  uint8
#  51  REGION_Southwest                    1046653 non-null  uint8
#  52  REGION_Upper Midwest                1046653 non-null  uint8
#  53  REGION_West                         1046653 non-null  uint8
# dtypes: float64(11), int64(5), object(14), uint8(24)
# memory usage: 271.5+ MB

# %%
combined_df_test = pd.get_dummies(fires_test, columns = ['STAT_CAUSE_DESCR', 'REGION'])
combined_df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 261664 entries, 533172 to 852601
# Data columns (total 54 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Unnamed: 0                          261664 non-null  int64
#  1   OBJECTID                            261664 non-null  int64
#  2   SOURCE_SYSTEM_TYPE                  261664 non-null  object
#  3   SOURCE_SYSTEM                       261664 non-null  object
#  4   NWCG_REPORTING_AGENCY               261664 non-null  object
#  5   NWCG_REPORTING_UNIT_ID              261664 non-null  object
#  6   NWCG_REPORTING_UNIT_NAME            261664 non-null  object
#  7   SOURCE_REPORTING_UNIT               261664 non-null  object
#  8   SOURCE_REPORTING_UNIT_NAME          261664 non-null  object
#  9   FIRE_NAME                           140208 non-null  object
#  10  FIRE_YEAR                           261664 non-null  int64
#  11  DISCOVERY_DATE                      261664 non-null  float64
#  12  DISCOVERY_DOY                       261664 non-null  int64
#  13  DISCOVERY_TIME                      140448 non-null  float64
#  14  STAT_CAUSE_CODE                     261664 non-null  float64
#  15  CONT_DATE                           135562 non-null  float64
#  16  CONT_DOY                            135562 non-null  float64
#  17  CONT_TIME                           125118 non-null  float64
#  18  FIRE_SIZE                           261664 non-null  float64
#  19  FIRE_SIZE_CLASS                     261664 non-null  object
#  20  LATITUDE                            261664 non-null  float64
#  21  LONGITUDE                           261664 non-null  float64
#  22  OWNER_CODE                          261664 non-null  float64
#  23  OWNER_DESCR                         261664 non-null  object
#  24  STATE                               261664 non-null  object
#  25  Shape                               261664 non-null  object
#  26  DAYS_TO_CONTAIN                     261664 non-null  float64
#  27  DISCOVERY_DATE_DT                   261664 non-null  object
#  28  CONT_DATE_DT                        135562 non-null  object
#  29  FIRE_SIZE_CLASS_BIN                 261664 non-null  int64
#  30  STAT_CAUSE_DESCR_Arson              261664 non-null  uint8
#  31  STAT_CAUSE_DESCR_Campfire           261664 non-null  uint8
#  32  STAT_CAUSE_DESCR_Children           261664 non-null  uint8
#  33  STAT_CAUSE_DESCR_Debris Burning     261664 non-null  uint8
#  34  STAT_CAUSE_DESCR_Equipment Use      261664 non-null  uint8
#  35  STAT_CAUSE_DESCR_Fireworks          261664 non-null  uint8
#  36  STAT_CAUSE_DESCR_Lightning          261664 non-null  uint8
#  37  STAT_CAUSE_DESCR_Miscellaneous      261664 non-null  uint8
#  38  STAT_CAUSE_DESCR_Missing/Undefined  261664 non-null  uint8
#  39  STAT_CAUSE_DESCR_Powerline          261664 non-null  uint8
#  40  STAT_CAUSE_DESCR_Railroad           261664 non-null  uint8
#  41  STAT_CAUSE_DESCR_Smoking            261664 non-null  uint8
#  42  STAT_CAUSE_DESCR_Structure          261664 non-null  uint8
#  43  REGION_Alaska                       261664 non-null  uint8
#  44  REGION_Northeast                    261664 non-null  uint8
#  45  REGION_Northern Rockies             261664 non-null  uint8
#  46  REGION_Northwest                    261664 non-null  uint8
#  47  REGION_Ohio Valley                  261664 non-null  uint8
#  48  REGION_Other                        261664 non-null  uint8
#  49  REGION_South                        261664 non-null  uint8
#  50  REGION_Southeast                    261664 non-null  uint8
#  51  REGION_Southwest                    261664 non-null  uint8
#  52  REGION_Upper Midwest                261664 non-null  uint8
#  53  REGION_West                         261664 non-null  uint8
# dtypes: float64(11), int64(5), object(14), uint8(24)
# memory usage: 67.9+ MB

# %% [markdown]
# <br>

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# ##### First Model - Fire Cause Only

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(combined_df[['STAT_CAUSE_DESCR_Campfire', 
                    'STAT_CAUSE_DESCR_Children', 'STAT_CAUSE_DESCR_Debris Burning',
                     'STAT_CAUSE_DESCR_Equipment Use', 'STAT_CAUSE_DESCR_Fireworks',
                     'STAT_CAUSE_DESCR_Lightning', 'STAT_CAUSE_DESCR_Miscellaneous', 
                     'STAT_CAUSE_DESCR_Missing/Undefined', 'STAT_CAUSE_DESCR_Powerline',             
                     'STAT_CAUSE_DESCR_Railroad', 'STAT_CAUSE_DESCR_Smoking',
                      'STAT_CAUSE_DESCR_Structure']])
y_train = combined_df['FIRE_SIZE_CLASS_BIN']

# %%
lm_1 = LogisticRegressionCV()
lm_1.fit(X_train, y_train)
lm_1.score(X_train, y_train)
# Out:
# 0.559982616597199

# %%
X_test = scaler.transform(combined_df_test[['STAT_CAUSE_DESCR_Campfire', 
                    'STAT_CAUSE_DESCR_Children', 'STAT_CAUSE_DESCR_Debris Burning',
                     'STAT_CAUSE_DESCR_Equipment Use', 'STAT_CAUSE_DESCR_Fireworks',
                     'STAT_CAUSE_DESCR_Lightning', 'STAT_CAUSE_DESCR_Miscellaneous', 
                     'STAT_CAUSE_DESCR_Missing/Undefined', 'STAT_CAUSE_DESCR_Powerline',             
                     'STAT_CAUSE_DESCR_Railroad', 'STAT_CAUSE_DESCR_Smoking',
                      'STAT_CAUSE_DESCR_Structure']])


preds = lm_1.predict(X_test)

conf_matrix = confusion_matrix(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
sns.heatmap(conf_matrix, cmap=plt.cm.Blues, annot=True, square=True, fmt='d')
plt.xlabel('prediction')
plt.ylabel('actual');

# %%
f1_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.5523263529474214

# %%
recall_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.5490475436652419

# %%
precision_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.5556445583680444

# %% [markdown]
# ##### Second Model - Region Only

# %%
X_train = scaler.fit_transform(combined_df[['REGION_Other', 
                    'REGION_Northeast', 'REGION_Northern Rockies',
                     'REGION_Northwest', 'REGION_Ohio Valley',
                     'REGION_South', 'REGION_Southeast', 
                     'REGION_Southwest', 'REGION_Upper Midwest',             
                     'REGION_West']])
y_train = combined_df['FIRE_SIZE_CLASS_BIN']

# %%
lm_2 = LogisticRegressionCV()
lm_2.fit(X_train, y_train)
lm_2.score(X_train, y_train)
# Out:
# 0.5758515562754742

# %%
X_test = scaler.transform(combined_df_test[[ 'REGION_Other', 
                    'REGION_Northeast', 'REGION_Northern Rockies',
                     'REGION_Northwest', 'REGION_Ohio Valley',
                     'REGION_South', 'REGION_Southeast', 
                     'REGION_Southwest', 'REGION_Upper Midwest',             
                     'REGION_West']])


preds = lm_2.predict(X_test)

conf_matrix = confusion_matrix(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
sns.heatmap(conf_matrix, cmap=plt.cm.Blues, annot=True, square=True, fmt='d')
plt.xlabel('prediction')
plt.ylabel('actual');

# %%
f1_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.49650789655823313

# %%
recall_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.4163896364307952

# %%
precision_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.6148032723022984

# %% [markdown]
# ##### Third Model - Latitude and Longitude Only

# %%
X_train = scaler.fit_transform(combined_df[['LATITUDE', 'LONGITUDE']])

y_train = combined_df['FIRE_SIZE_CLASS_BIN']

# %%
lm_3 = LogisticRegressionCV()
lm_3.fit(X_train, y_train)
lm_3.score(X_train, y_train)
# Out:
# 0.5972647479077363

# %%
X_test = scaler.transform(combined_df_test[['LATITUDE', 'LONGITUDE']])


preds = lm_3.predict(X_test)

conf_matrix = confusion_matrix(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
sns.heatmap(conf_matrix, cmap=plt.cm.Blues, annot=True, square=True, fmt='d')
plt.xlabel('prediction')
plt.ylabel('actual');

# %%
f1_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.5438805259713215

# %%
recall_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.48234921640018996

# %%
precision_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.6234058514628658

# %% [markdown]
# ##### Fourth Model - Discovery Day of Year Only

# %%
X_train = scaler.fit_transform(combined_df[['DISCOVERY_DOY']])

y_train = combined_df['FIRE_SIZE_CLASS_BIN']

# %%
lm_4 = LogisticRegressionCV()
lm_4.fit(X_train, y_train)
lm_4.score(X_train, y_train)
# Out:
# 0.5382138553621871

# %%
X_test = scaler.transform(combined_df_test[['DISCOVERY_DOY']])


preds = lm_4.predict(X_test)

conf_matrix = confusion_matrix(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
sns.heatmap(conf_matrix, cmap=plt.cm.Blues, annot=True, square=True, fmt='d')
plt.xlabel('prediction')
plt.ylabel('actual');

# %%
f1_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.5181608690881159

# %%
recall_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.4983378185847713

# %%
precision_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.5396263070681675

# %% [markdown]
# ##### Fifth Model - Region and Fire Cause

# %%
X_train = scaler.fit_transform(combined_df[['STAT_CAUSE_DESCR_Campfire', 
                    'STAT_CAUSE_DESCR_Children', 'STAT_CAUSE_DESCR_Debris Burning',
                     'STAT_CAUSE_DESCR_Equipment Use', 'STAT_CAUSE_DESCR_Fireworks',
                     'STAT_CAUSE_DESCR_Lightning', 'STAT_CAUSE_DESCR_Miscellaneous', 
                     'STAT_CAUSE_DESCR_Missing/Undefined', 'STAT_CAUSE_DESCR_Powerline',             
                     'STAT_CAUSE_DESCR_Railroad', 'STAT_CAUSE_DESCR_Smoking',
                      'STAT_CAUSE_DESCR_Structure', 'REGION_Other', 
                    'REGION_Northeast', 'REGION_Northern Rockies',
                     'REGION_Northwest', 'REGION_Ohio Valley',
                     'REGION_South', 'REGION_Southeast', 
                     'REGION_Southwest', 'REGION_Upper Midwest',             
                     'REGION_West']])

y_train = combined_df['FIRE_SIZE_CLASS_BIN']

# %%
lm_5 = LogisticRegressionCV()
lm_5.fit(X_train, y_train)
lm_5.score(X_train, y_train)
# Out:
# 0.5894883090031541

# %%
X_test = scaler.transform(combined_df_test[['STAT_CAUSE_DESCR_Campfire', 
                    'STAT_CAUSE_DESCR_Children', 'STAT_CAUSE_DESCR_Debris Burning',
                     'STAT_CAUSE_DESCR_Equipment Use', 'STAT_CAUSE_DESCR_Fireworks',
                     'STAT_CAUSE_DESCR_Lightning', 'STAT_CAUSE_DESCR_Miscellaneous', 
                     'STAT_CAUSE_DESCR_Missing/Undefined', 'STAT_CAUSE_DESCR_Powerline',             
                     'STAT_CAUSE_DESCR_Railroad', 'STAT_CAUSE_DESCR_Smoking',
                      'STAT_CAUSE_DESCR_Structure', 'REGION_Other', 
                    'REGION_Northeast', 'REGION_Northern Rockies',
                     'REGION_Northwest', 'REGION_Ohio Valley',
                     'REGION_South', 'REGION_Southeast', 
                     'REGION_Southwest', 'REGION_Upper Midwest',             
                     'REGION_West']])


preds = lm_5.predict(X_test)

conf_matrix = confusion_matrix(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
sns.heatmap(conf_matrix, cmap=plt.cm.Blues, annot=True, square=True, fmt='d')
plt.xlabel('prediction')
plt.ylabel('actual');

# %%
f1_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.5724985752666287

# %%
recall_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.5565933196137407

# %%
precision_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.589339591015756

# %% [markdown]
# ##### Sixth Model - Region, Fire Cause, and Discovery Day of Year

# %%
X_train = scaler.fit_transform(combined_df[['STAT_CAUSE_DESCR_Campfire', 
                    'STAT_CAUSE_DESCR_Children', 'STAT_CAUSE_DESCR_Debris Burning',
                     'STAT_CAUSE_DESCR_Equipment Use', 'STAT_CAUSE_DESCR_Fireworks',
                     'STAT_CAUSE_DESCR_Lightning', 'STAT_CAUSE_DESCR_Miscellaneous', 
                     'STAT_CAUSE_DESCR_Missing/Undefined', 'STAT_CAUSE_DESCR_Powerline',             
                     'STAT_CAUSE_DESCR_Railroad', 'STAT_CAUSE_DESCR_Smoking',
                      'STAT_CAUSE_DESCR_Structure', 'REGION_Other', 
                    'REGION_Northeast', 'REGION_Northern Rockies',
                     'REGION_Northwest', 'REGION_Ohio Valley',
                     'REGION_South', 'REGION_Southeast', 
                     'REGION_Southwest', 'REGION_Upper Midwest',             
                     'REGION_West', 'DISCOVERY_DOY']])

y_train = combined_df['FIRE_SIZE_CLASS_BIN']

# %%
lm_6 = LogisticRegressionCV()
lm_6.fit(X_train, y_train)
lm_6.score(X_train, y_train)
# Out:
# 0.5915229572855553

# %%
X_test = scaler.transform(combined_df_test[['STAT_CAUSE_DESCR_Campfire', 
                    'STAT_CAUSE_DESCR_Children', 'STAT_CAUSE_DESCR_Debris Burning',
                     'STAT_CAUSE_DESCR_Equipment Use', 'STAT_CAUSE_DESCR_Fireworks',
                     'STAT_CAUSE_DESCR_Lightning', 'STAT_CAUSE_DESCR_Miscellaneous', 
                     'STAT_CAUSE_DESCR_Missing/Undefined', 'STAT_CAUSE_DESCR_Powerline',             
                     'STAT_CAUSE_DESCR_Railroad', 'STAT_CAUSE_DESCR_Smoking',
                      'STAT_CAUSE_DESCR_Structure', 'REGION_Other', 
                    'REGION_Northeast', 'REGION_Northern Rockies',
                     'REGION_Northwest', 'REGION_Ohio Valley',
                     'REGION_South', 'REGION_Southeast', 
                     'REGION_Southwest', 'REGION_Upper Midwest',             
                     'REGION_West', 'DISCOVERY_DOY']])


preds = lm_6.predict(X_test)

conf_matrix = confusion_matrix(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
sns.heatmap(conf_matrix, cmap=plt.cm.Blues, annot=True, square=True, fmt='d')
plt.xlabel('prediction')
plt.ylabel('actual');

# %%
f1_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.5910848662207357

# %%
recall_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.5968550472270593

# %%
precision_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.5854251850318306

# %% [markdown]
# <br>

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.model_selection import cross_val_score

X_train = combined_df[['REGION_Other', 
                    'REGION_Northeast', 'REGION_Northern Rockies',
                     'REGION_Northwest', 'REGION_Ohio Valley',
                     'REGION_South', 'REGION_Southeast', 
                     'REGION_Southwest', 'REGION_Upper Midwest',             
                     'REGION_West', 'STAT_CAUSE_DESCR_Campfire', 
                    'STAT_CAUSE_DESCR_Children', 'STAT_CAUSE_DESCR_Debris Burning',
                     'STAT_CAUSE_DESCR_Equipment Use', 'STAT_CAUSE_DESCR_Fireworks',
                     'STAT_CAUSE_DESCR_Lightning', 'STAT_CAUSE_DESCR_Miscellaneous', 
                     'STAT_CAUSE_DESCR_Missing/Undefined', 'STAT_CAUSE_DESCR_Powerline',             
                     'STAT_CAUSE_DESCR_Railroad', 'STAT_CAUSE_DESCR_Smoking',
                      'STAT_CAUSE_DESCR_Structure', 'DISCOVERY_DATE',
                      'LATITUDE', 'LONGITUDE']]

y_train = combined_df['FIRE_SIZE_CLASS_BIN']


knn = KNeighborsClassifier(n_neighbors=3)
scores = cross_val_score(knn, X_train, y_train, cv=10, scoring='recall')
print(scores)
# Out:
# [0.58173203 0.57831008 0.57804685 0.59120821 0.59949987 0.5968676
#  0.58765465 0.5852856  0.58647012 0.58949724]

# %%
knn = KNeighborsClassifier(n_neighbors=10)
scores = cross_val_score(knn, X_train, y_train, cv=10, scoring='recall')
print(scores)
# Out:
# [0.50592261 0.50605422 0.51539879 0.50605422 0.51908397 0.51197684
#  0.51763622 0.51039747 0.5126349  0.51539879]

# %% [markdown]
# <br>

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import train_test_split

def quick_test(model, X, y):
    xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.3)
    model.fit(xtrain, ytrain)
    return model.score(xtest, ytest)

def quick_test_afew_times(model, X, y, n=10):
    return np.mean([quick_test(model, X, y) for j in range(n)])

# %%
X_train = combined_df[['REGION_Alaska', 'REGION_Other', 
                    'REGION_Northeast', 'REGION_Northern Rockies',
                     'REGION_Northwest', 'REGION_Ohio Valley',
                     'REGION_South', 'REGION_Southeast', 
                     'REGION_Southwest', 'REGION_Upper Midwest',             
                     'REGION_West', 'STAT_CAUSE_DESCR_Campfire', 
                     'STAT_CAUSE_DESCR_Arson', 
                    'STAT_CAUSE_DESCR_Children', 'STAT_CAUSE_DESCR_Debris Burning',
                     'STAT_CAUSE_DESCR_Equipment Use', 'STAT_CAUSE_DESCR_Fireworks',
                     'STAT_CAUSE_DESCR_Lightning', 'STAT_CAUSE_DESCR_Miscellaneous', 
                     'STAT_CAUSE_DESCR_Missing/Undefined', 'STAT_CAUSE_DESCR_Powerline',             
                     'STAT_CAUSE_DESCR_Railroad', 'STAT_CAUSE_DESCR_Smoking',
                      'STAT_CAUSE_DESCR_Structure', 'DISCOVERY_DATE', 'DISCOVERY_DOY',
                      'LATITUDE', 'LONGITUDE']]

y_train = combined_df['FIRE_SIZE_CLASS_BIN']

# %%
randomforest = RandomForestClassifier(n_estimators=100)
quick_test_afew_times(randomforest, X_train, y_train)
# Out:
# 0.6154408375584381

# %%
X_test = (combined_df_test[['REGION_Alaska', 'REGION_Other', 
                    'REGION_Northeast', 'REGION_Northern Rockies',
                     'REGION_Northwest', 'REGION_Ohio Valley',
                     'REGION_South', 'REGION_Southeast', 
                     'REGION_Southwest', 'REGION_Upper Midwest',             
                     'REGION_West', 'STAT_CAUSE_DESCR_Campfire',
                     'STAT_CAUSE_DESCR_Arson', 
                    'STAT_CAUSE_DESCR_Children', 'STAT_CAUSE_DESCR_Debris Burning',
                     'STAT_CAUSE_DESCR_Equipment Use', 'STAT_CAUSE_DESCR_Fireworks',
                     'STAT_CAUSE_DESCR_Lightning', 'STAT_CAUSE_DESCR_Miscellaneous', 
                     'STAT_CAUSE_DESCR_Missing/Undefined', 'STAT_CAUSE_DESCR_Powerline',             
                     'STAT_CAUSE_DESCR_Railroad', 'STAT_CAUSE_DESCR_Smoking',
                      'STAT_CAUSE_DESCR_Structure', 'DISCOVERY_DATE', 'DISCOVERY_DOY',
                      'LATITUDE', 'LONGITUDE']])


preds = randomforest.predict(X_test)

# %%
conf_matrix = confusion_matrix(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
sns.heatmap(conf_matrix, cmap=plt.cm.Blues, annot=True, square=True, fmt='d')
plt.xlabel('prediction')
plt.ylabel('actual');

# %%
f1_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.6116387959866221

# %%
recall_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.6031343992401457

# %%
precision_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.6203864524533218

# %%
combined_df_test['proba_lrg'] = randomforest.predict_proba(combined_df_test[['REGION_Alaska', 'REGION_Other', 
                    'REGION_Northeast', 'REGION_Northern Rockies',
                     'REGION_Northwest', 'REGION_Ohio Valley',
                     'REGION_South', 'REGION_Southeast', 
                     'REGION_Southwest', 'REGION_Upper Midwest',             
                     'REGION_West', 'STAT_CAUSE_DESCR_Campfire',
                     'STAT_CAUSE_DESCR_Arson', 
                    'STAT_CAUSE_DESCR_Children', 'STAT_CAUSE_DESCR_Debris Burning',
                     'STAT_CAUSE_DESCR_Equipment Use', 'STAT_CAUSE_DESCR_Fireworks',
                     'STAT_CAUSE_DESCR_Lightning', 'STAT_CAUSE_DESCR_Miscellaneous', 
                     'STAT_CAUSE_DESCR_Missing/Undefined', 'STAT_CAUSE_DESCR_Powerline',             
                     'STAT_CAUSE_DESCR_Railroad', 'STAT_CAUSE_DESCR_Smoking',
                      'STAT_CAUSE_DESCR_Structure', 'DISCOVERY_DATE', 'DISCOVERY_DOY',
                      'LATITUDE', 'LONGITUDE']])[:, 1]

fpr, tpr, thresholds = roc_curve(combined_df_test['FIRE_SIZE_CLASS_BIN'],
                                 combined_df_test['proba_lrg'])

def plot_roc(true, probas):
    auc = roc_auc_score(true, probas)

    plt.plot(fpr, tpr, marker='o')
    plt.xlabel('1 - Specificity (FPR)')
    plt.ylabel('Sensitivity (TPR)');
    plt.title(f"Area Under the ROC Curve: {round(auc, 3)}");

# %%
plot_roc(combined_df_test['FIRE_SIZE_CLASS_BIN'], randomforest.predict_proba(X_test)[:, 1])

# %% [markdown]
# <br>

# %% [markdown]
# ### XGBoost

# %%
import xgboost as xgb
