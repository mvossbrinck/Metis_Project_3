# %%
# Import packages and connect to database
import sqlite3
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import pickle

# %config InlineBackend.figure_formats = ['svg']
# %matplotlib inline

from sklearn.preprocessing import OneHotEncoder
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegressionCV
from sklearn.metrics import roc_auc_score, confusion_matrix, roc_curve
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import precision_score, recall_score, precision_recall_curve,f1_score, fbeta_score

# %%
### Data Cleaning

# %%
with open('More_Than_1Acre.pickle','rb') as read_file:
    fires = pickle.load(read_file)

# %%
fires.to_csv('firedata.csv')

# %%
fires['FIRE_SIZE_CLASS'].value_counts()
# Out:
# B    472539
# C    220077
# D     28427
# E     14107
# F      7786
# G      3773
# Name: FIRE_SIZE_CLASS, dtype: int64

# %%
fires['FIRE_SIZE_CLASS_BIN'] = np.where(fires['FIRE_SIZE_CLASS'].isin(['B']), 0, 1)

# %%
# NOAA climate regions
fires['REGION'] = np.where(fires['STATE'].isin(['WA', 'OR', 'ID']), 'Northwest', 
                  np.where(fires['STATE'].isin(['CA', 'NV']), 'West', 
                  np.where(fires['STATE'].isin(['MT', 'NE', 'ND', 'SD', 'WY']), 'Northern Rockies', 
                  np.where(fires['STATE'].isin(['AK', 'HI']), 'Alaska_Hawaii', 
                  np.where(fires['STATE'].isin(['AZ', 'NM', 'CO', 'UT']), 'Southwest',          
                  np.where(fires['STATE'].isin(['OK', 'TX', 'KS', 'AR', 'LA', 'MS']), 'South', 
                  np.where(fires['STATE'].isin(['AL', 'FL', 'GA', 'NC', 'SC', 'VA']), 'Southeast', 
                  np.where(fires['STATE'].isin(['IL', 'IN', 'KY', 'MO', 'TN', 'OH', 'WV']), 'Ohio Valley', 
                  np.where(fires['STATE'].isin(['IA',  'MI', 'MN', 'WI']), 'Upper Midwest', 
                  np.where(fires['STATE'].isin(['CT', 'NY', 'ME', 'MA', 'MD', 'NH', 'NJ', 'PA', 'RI', 'VT', 'DE']), 'Northeast', 'None'        
                                  ))))))))))

# %%
fires['REGION'].value_counts()
# Out:
# Southeast           254930
# South               207321
# Ohio Valley          64018
# West                 44582
# Southwest            39742
# Northern Rockies     35196
# Upper Midwest        29912
# Northeast            29189
# Northwest            26079
# None                 10192
# Alaska_Hawaii         5548
# Name: REGION, dtype: int64

# %%
# Creating new date variables
fires['DAYS_TO_CONTAIN'] = fires['CONT_DATE'] - fires['DISCOVERY_DATE'] 
fires['DAYS_TO_CONTAIN'] = fires['DAYS_TO_CONTAIN'].fillna(0)
fires['DISCOVERY_DATE_DT'] = pd.to_datetime(fires['DISCOVERY_DATE'], unit='D', origin='julian')
fires['CONT_DATE_DT'] = pd.to_datetime(fires['CONT_DATE'], unit='D', origin='julian')

# %%
combined_df.corr()
# Out:
#                                     OBJECTID    FOD_ID  FIRE_YEAR  \
# OBJECTID                            1.000000  0.733259   0.477891
# FOD_ID                              0.733259  1.000000   0.674608
# FIRE_YEAR                           0.477891  0.674608   1.000000
# DISCOVERY_DATE                      0.475426  0.673249   0.999218
# DISCOVERY_DOY                      -0.053619 -0.021916  -0.001496
# STAT_CAUSE_CODE                     0.087201  0.036191  -0.006610
# CONT_DATE                           0.603812  0.755777   0.999436
# CONT_DOY                           -0.109595 -0.035071   0.022673
# FIRE_SIZE                          -0.019822  0.007092   0.013530
# LATITUDE                           -0.169328 -0.060076   0.011583
# LONGITUDE                           0.201895 -0.022275  -0.011569
# OWNER_CODE                          0.108698 -0.145797  -0.094246
# FIRE_SIZE_CLASS_BIN                -0.052913  0.009083   0.023924
# DAYS_TO_CONTAIN                    -0.024416  0.032252   0.040084
# STAT_CAUSE_DESCR_Campfire           0.015098  0.020333   0.011350
# STAT_CAUSE_DESCR_Children          -0.017695 -0.025815  -0.036531
# STAT_CAUSE_DESCR_Debris Burning     0.093839  0.033013   0.038208
# STAT_CAUSE_DESCR_Equipment Use      0.021850  0.005470   0.010487
# STAT_CAUSE_DESCR_Fireworks          0.001491  0.011043   0.014358
# STAT_CAUSE_DESCR_Lightning         -0.157543 -0.004026   0.023956
# STAT_CAUSE_DESCR_Miscellaneous      0.042798  0.052313   0.088844
# STAT_CAUSE_DESCR_Missing/Undefined  0.032360  0.038768  -0.027952
# STAT_CAUSE_DESCR_Powerline          0.061490  0.087818   0.073277
# STAT_CAUSE_DESCR_Railroad          -0.003703 -0.048941  -0.086910
# STAT_CAUSE_DESCR_Smoking           -0.006563 -0.022822  -0.039373
# STAT_CAUSE_DESCR_Structure          0.025561  0.027432   0.027610
# REGION_None                         0.173621  0.181933   0.053410
# REGION_Northeast                    0.107908  0.009079   0.066019
# REGION_Northern Rockies            -0.108506  0.018242   0.032588
# REGION_Northwest                   -0.110791  0.000081  -0.001217
# REGION_Ohio Valley                  0.056279 -0.008948   0.022697
# REGION_South                        0.014154  0.074363   0.112599
# REGION_Southeast                    0.075448 -0.098306  -0.123704
# REGION_Southwest                   -0.180797 -0.049214  -0.063219
# REGION_Upper Midwest               -0.052612 -0.009645  -0.008473
# REGION_West                        -0.019815 -0.009659  -0.038239
#
#                                     DISCOVERY_DATE  DISCOVERY_DOY  \
# OBJECTID                                  0.475426      -0.053619
# FOD_ID                                    0.673249      -0.021916
# FIRE_YEAR                                 0.999218      -0.001496
# DISCOVERY_DATE                            1.000000       0.038041
# DISCOVERY_DOY                             0.038041       1.000000
# STAT_CAUSE_CODE                          -0.010955      -0.110028
# CONT_DATE                                 0.999988       0.049917
# CONT_DOY                                  0.055434       0.993131
# FIRE_SIZE                                 0.014115       0.015077
# LATITUDE                                  0.016165       0.116144
# LONGITUDE                                -0.020265      -0.220222
# OWNER_CODE                               -0.098110      -0.099472
# FIRE_SIZE_CLASS_BIN                       0.024174       0.006806
# DAYS_TO_CONTAIN                           0.041321       0.032032
# STAT_CAUSE_DESCR_Campfire                 0.011653       0.007875
# STAT_CAUSE_DESCR_Children                -0.037012      -0.012814
# STAT_CAUSE_DESCR_Debris Burning           0.034062      -0.104186
# STAT_CAUSE_DESCR_Equipment Use            0.012810       0.058975
# STAT_CAUSE_DESCR_Fireworks                0.015271       0.023327
# STAT_CAUSE_DESCR_Lightning                0.030218       0.158859
# STAT_CAUSE_DESCR_Miscellaneous            0.089910       0.028616
# STAT_CAUSE_DESCR_Missing/Undefined       -0.030314      -0.060264
# STAT_CAUSE_DESCR_Powerline                0.073755       0.013439
# STAT_CAUSE_DESCR_Railroad                -0.087896      -0.026491
# STAT_CAUSE_DESCR_Smoking                 -0.039014       0.008363
# STAT_CAUSE_DESCR_Structure                0.027644       0.001347
# REGION_None                               0.050121      -0.082280
# REGION_Northeast                          0.064562      -0.035695
# REGION_Northern Rockies                   0.035313       0.069607
# REGION_Northwest                          0.003348       0.115459
# REGION_Ohio Valley                        0.022770       0.002160
# REGION_South                              0.112351      -0.004197
# REGION_Southeast                         -0.128563      -0.125117
# REGION_Southwest                         -0.060844       0.058878
# REGION_Upper Midwest                     -0.009839      -0.034695
# REGION_West                              -0.032757       0.137981
#
#                                     STAT_CAUSE_CODE  CONT_DATE  CONT_DOY  \
# OBJECTID                                   0.087201   0.603812 -0.109595
# FOD_ID                                     0.036191   0.755777 -0.035071
# FIRE_YEAR                                 -0.006610   0.999436  0.022673
# DISCOVERY_DATE                            -0.010955   0.999988  0.055434
# DISCOVERY_DOY                             -0.110028   0.049917  0.993131
# STAT_CAUSE_CODE                            1.000000  -0.112014 -0.166979
# CONT_DATE                                 -0.112014   1.000000  0.056002
# CONT_DOY                                  -0.166979   0.056002  1.000000
# FIRE_SIZE                                 -0.038367   0.013551  0.046735
# LATITUDE                                  -0.142427   0.056944  0.154214
# LONGITUDE                                  0.173244   0.015917 -0.272044
# OWNER_CODE                                 0.201697  -0.014851 -0.160070
# FIRE_SIZE_CLASS_BIN                       -0.019796   0.028392  0.035749
# DAYS_TO_CONTAIN                           -0.078342   0.048074  0.116928
# STAT_CAUSE_DESCR_Campfire                 -0.107111   0.050747  0.007551
# STAT_CAUSE_DESCR_Children                  0.081514  -0.026116 -0.013920
# STAT_CAUSE_DESCR_Debris Burning           -0.216273   0.057296 -0.138617
# STAT_CAUSE_DESCR_Equipment Use            -0.359508   0.048535  0.058056
# STAT_CAUSE_DESCR_Fireworks                 0.069075   0.009710  0.030643
# STAT_CAUSE_DESCR_Lightning                -0.543241   0.024744  0.235947
# STAT_CAUSE_DESCR_Miscellaneous             0.350585   0.125810  0.016516
# STAT_CAUSE_DESCR_Missing/Undefined         0.666377  -0.197099 -0.073314
# STAT_CAUSE_DESCR_Powerline                 0.130548   0.050588  0.016705
# STAT_CAUSE_DESCR_Railroad                 -0.007080  -0.017202  0.004350
# STAT_CAUSE_DESCR_Smoking                  -0.140776  -0.038938  0.007727
# STAT_CAUSE_DESCR_Structure                 0.059540   0.028730  0.000544
# REGION_None                                0.240272   0.013029 -0.013521
# REGION_Northeast                           0.053273   0.094489 -0.056642
# REGION_Northern Rockies                   -0.073674   0.005000  0.082135
# REGION_Northwest                          -0.108071  -0.000074  0.175174
# REGION_Ohio Valley                         0.032862   0.095225 -0.010443
# REGION_South                               0.091952  -0.048099 -0.076351
# REGION_Southeast                          -0.051396  -0.033873 -0.153448
# REGION_Southwest                          -0.055073  -0.080902  0.086046
# REGION_Upper Midwest                       0.000139   0.021113 -0.043811
# REGION_West                               -0.057271   0.010006  0.138278
#
#                                     FIRE_SIZE  LATITUDE  ...  REGION_None  \
# OBJECTID                            -0.019822 -0.169328  ...     0.173621
# FOD_ID                               0.007092 -0.060076  ...     0.181933
# FIRE_YEAR                            0.013530  0.011583  ...     0.053410
# DISCOVERY_DATE                       0.014115  0.016165  ...     0.050121
# DISCOVERY_DOY                        0.015077  0.116144  ...    -0.082280
# STAT_CAUSE_CODE                     -0.038367 -0.142427  ...     0.240272
# CONT_DATE                            0.013551  0.056944  ...     0.013029
# CONT_DOY                             0.046735  0.154214  ...    -0.013521
# FIRE_SIZE                            1.000000  0.077068  ...    -0.005219
# LATITUDE                             0.077068  1.000000  ...    -0.353076
# LONGITUDE                           -0.089908 -0.443801  ...     0.221507
# OWNER_CODE                          -0.059461 -0.323962  ...     0.075372
# FIRE_SIZE_CLASS_BIN                  0.061352  0.020127  ...    -0.022797
# DAYS_TO_CONTAIN                      0.175992  0.134952  ...    -0.010042
# STAT_CAUSE_DESCR_Campfire           -0.000204  0.030700  ...    -0.019243
# STAT_CAUSE_DESCR_Children           -0.005811  0.019787  ...    -0.017116
# STAT_CAUSE_DESCR_Debris Burning     -0.024891 -0.046716  ...    -0.072245
# STAT_CAUSE_DESCR_Equipment Use      -0.004662  0.005789  ...    -0.033547
# STAT_CAUSE_DESCR_Fireworks          -0.000909  0.046149  ...    -0.006988
# STAT_CAUSE_DESCR_Lightning           0.078359  0.161842  ...    -0.040824
# STAT_CAUSE_DESCR_Miscellaneous      -0.005532  0.047172  ...    -0.045402
# STAT_CAUSE_DESCR_Missing/Undefined  -0.004858 -0.137515  ...     0.358436
# STAT_CAUSE_DESCR_Powerline           0.001297  0.016408  ...    -0.010477
# STAT_CAUSE_DESCR_Railroad           -0.005018 -0.070199  ...    -0.017029
# STAT_CAUSE_DESCR_Smoking            -0.004784  0.019047  ...    -0.017191
# STAT_CAUSE_DESCR_Structure           0.000427  0.018866  ...    -0.003960
# REGION_None                         -0.005219 -0.353076  ...     1.000000
# REGION_Northeast                    -0.008966  0.234846  ...    -0.023726
# REGION_Northern Rockies              0.007759  0.377699  ...    -0.026113
# REGION_Northwest                     0.039685  0.321024  ...    -0.022372
# REGION_Ohio Valley                  -0.011467  0.094374  ...    -0.035963
# REGION_South                        -0.016574 -0.280621  ...    -0.072961
# REGION_Southeast                    -0.028222 -0.349473  ...    -0.084586
# REGION_Southwest                     0.016230  0.008832  ...    -0.027869
# REGION_Upper Midwest                -0.007057  0.365430  ...    -0.024020
# REGION_West                          0.018841  0.096518  ...    -0.029658
#
#                                     REGION_Northeast  REGION_Northern Rockies  \
# OBJECTID                                    0.107908                -0.108506
# FOD_ID                                      0.009079                 0.018242
# FIRE_YEAR                                   0.066019                 0.032588
# DISCOVERY_DATE                              0.064562                 0.035313
# DISCOVERY_DOY                              -0.035695                 0.069607
# STAT_CAUSE_CODE                             0.053273                -0.073674
# CONT_DATE                                   0.094489                 0.005000
# CONT_DOY                                   -0.056642                 0.082135
# FIRE_SIZE                                  -0.008966                 0.007759
# LATITUDE                                    0.234846                 0.377699
# LONGITUDE                                   0.262153                -0.189767
# OWNER_CODE                                  0.095006                -0.260588
# FIRE_SIZE_CLASS_BIN                        -0.112791                 0.043179
# DAYS_TO_CONTAIN                             0.018983                 0.025703
# STAT_CAUSE_DESCR_Campfire                   0.016085                -0.008872
# STAT_CAUSE_DESCR_Children                   0.013680                 0.029970
# STAT_CAUSE_DESCR_Debris Burning            -0.054287                -0.051264
# STAT_CAUSE_DESCR_Equipment Use             -0.027945                 0.016673
# STAT_CAUSE_DESCR_Fireworks                 -0.010683                 0.048219
# STAT_CAUSE_DESCR_Lightning                 -0.040599                 0.132632
# STAT_CAUSE_DESCR_Miscellaneous              0.145201                 0.006551
# STAT_CAUSE_DESCR_Missing/Undefined         -0.034230                -0.027020
# STAT_CAUSE_DESCR_Powerline                  0.001445                 0.008023
# STAT_CAUSE_DESCR_Railroad                  -0.015600                -0.007979
# STAT_CAUSE_DESCR_Smoking                    0.037598                 0.000291
# STAT_CAUSE_DESCR_Structure                 -0.000127                 0.008972
# REGION_None                                -0.023726                -0.026113
# REGION_Northeast                            1.000000                -0.044825
# REGION_Northern Rockies                    -0.044825                 1.000000
# REGION_Northwest                           -0.038402                -0.042267
# REGION_Ohio Valley                         -0.061733                -0.067945
# REGION_South                               -0.125243                -0.137845
# REGION_Southeast                           -0.145199                -0.159810
# REGION_Southwest                           -0.047840                -0.052654
# REGION_Upper Midwest                       -0.041231                -0.045380
# REGION_West                                -0.050911                -0.056034
#
#                                     REGION_Northwest  REGION_Ohio Valley  \
# OBJECTID                                   -0.110791            0.056279
# FOD_ID                                      0.000081           -0.008948
# FIRE_YEAR                                  -0.001217            0.022697
# DISCOVERY_DATE                              0.003348            0.022770
# DISCOVERY_DOY                               0.115459            0.002160
# STAT_CAUSE_CODE                            -0.108071            0.032862
# CONT_DATE                                  -0.000074            0.095225
# CONT_DOY                                    0.175174           -0.010443
# FIRE_SIZE                                   0.039685           -0.011467
# LATITUDE                                    0.321024            0.094374
# LONGITUDE                                  -0.364142            0.145871
# OWNER_CODE                                 -0.260831           -0.011042
# FIRE_SIZE_CLASS_BIN                         0.037717            0.058315
# DAYS_TO_CONTAIN                             0.112936           -0.017523
# STAT_CAUSE_DESCR_Campfire                   0.015686            0.035411
# STAT_CAUSE_DESCR_Children                  -0.011145           -0.025929
# STAT_CAUSE_DESCR_Debris Burning            -0.062620            0.070389
# STAT_CAUSE_DESCR_Equipment Use              0.003878           -0.044241
# STAT_CAUSE_DESCR_Fireworks                  0.038247            0.036380
# STAT_CAUSE_DESCR_Lightning                  0.198566           -0.097912
# STAT_CAUSE_DESCR_Miscellaneous              0.000718           -0.061481
# STAT_CAUSE_DESCR_Missing/Undefined         -0.026209           -0.016994
# STAT_CAUSE_DESCR_Powerline                  0.014899            0.006243
# STAT_CAUSE_DESCR_Railroad                  -0.009571           -0.019672
# STAT_CAUSE_DESCR_Smoking                   -0.004244           -0.013981
# STAT_CAUSE_DESCR_Structure                  0.002260            0.027760
# REGION_None                                -0.022372           -0.035963
# REGION_Northeast                           -0.038402           -0.061733
# REGION_Northern Rockies                    -0.042267           -0.067945
# REGION_Northwest                            1.000000           -0.058210
# REGION_Ohio Valley                         -0.058210            1.000000
# REGION_South                               -0.118094           -0.189840
# REGION_Southeast                           -0.136911           -0.220089
# REGION_Southwest                           -0.045109           -0.072515
# REGION_Upper Midwest                       -0.038878           -0.062498
# REGION_West                                -0.048005           -0.077169
#
#                                     REGION_South  REGION_Southeast  \
# OBJECTID                                0.014154          0.075448
# FOD_ID                                  0.074363         -0.098306
# FIRE_YEAR                               0.112599         -0.123704
# DISCOVERY_DATE                          0.112351         -0.128563
# DISCOVERY_DOY                          -0.004197         -0.125117
# STAT_CAUSE_CODE                         0.091952         -0.051396
# CONT_DATE                              -0.048099         -0.033873
# CONT_DOY                               -0.076351         -0.153448
# FIRE_SIZE                              -0.016574         -0.028222
# LATITUDE                               -0.280621         -0.349473
# LONGITUDE                              -0.070547          0.506942
# OWNER_CODE                              0.179551          0.179519
# FIRE_SIZE_CLASS_BIN                     0.077659         -0.111050
# DAYS_TO_CONTAIN                        -0.046509         -0.052748
# STAT_CAUSE_DESCR_Campfire              -0.028712         -0.014056
# STAT_CAUSE_DESCR_Children              -0.057837          0.051354
# STAT_CAUSE_DESCR_Debris Burning         0.018131          0.125467
# STAT_CAUSE_DESCR_Equipment Use         -0.020861         -0.014300
# STAT_CAUSE_DESCR_Fireworks             -0.020612         -0.033762
# STAT_CAUSE_DESCR_Lightning             -0.121339         -0.062354
# STAT_CAUSE_DESCR_Miscellaneous          0.059291         -0.107573
# STAT_CAUSE_DESCR_Missing/Undefined     -0.000407         -0.050375
# STAT_CAUSE_DESCR_Powerline              0.030097         -0.042194
# STAT_CAUSE_DESCR_Railroad              -0.059023          0.107877
# STAT_CAUSE_DESCR_Smoking               -0.012745          0.010585
# STAT_CAUSE_DESCR_Structure             -0.013797         -0.006288
# REGION_None                            -0.072961         -0.084586
# REGION_Northeast                       -0.125243         -0.145199
# REGION_Northern Rockies                -0.137845         -0.159810
# REGION_Northwest                       -0.118094         -0.136911
# REGION_Ohio Valley                     -0.189840         -0.220089
# REGION_South                            1.000000         -0.446510
# REGION_Southeast                       -0.446510          1.000000
# REGION_Southwest                       -0.147116         -0.170557
# REGION_Upper Midwest                   -0.126793         -0.146996
# REGION_West                            -0.156558         -0.181505
#
#                                     REGION_Southwest  REGION_Upper Midwest  \
# OBJECTID                                   -0.180797             -0.052612
# FOD_ID                                     -0.049214             -0.009645
# FIRE_YEAR                                  -0.063219             -0.008473
# DISCOVERY_DATE                             -0.060844             -0.009839
# DISCOVERY_DOY                               0.058878             -0.034695
# STAT_CAUSE_CODE                            -0.055073              0.000139
# CONT_DATE                                  -0.080902              0.021113
# CONT_DOY                                    0.086046             -0.043811
# FIRE_SIZE                                   0.016230             -0.007057
# LATITUDE                                    0.008832              0.365430
# LONGITUDE                                  -0.293215              0.004913
# OWNER_CODE                                 -0.288866             -0.013455
# FIRE_SIZE_CLASS_BIN                         0.038264             -0.026448
# DAYS_TO_CONTAIN                             0.044314             -0.014204
# STAT_CAUSE_DESCR_Campfire                   0.015987              0.024333
# STAT_CAUSE_DESCR_Children                  -0.004177              0.021758
# STAT_CAUSE_DESCR_Debris Burning            -0.100808              0.035852
# STAT_CAUSE_DESCR_Equipment Use             -0.032084              0.008015
# STAT_CAUSE_DESCR_Fireworks                  0.005932             -0.000326
# STAT_CAUSE_DESCR_Lightning                  0.222463             -0.057624
# STAT_CAUSE_DESCR_Miscellaneous              0.003865             -0.007057
# STAT_CAUSE_DESCR_Missing/Undefined          0.060188             -0.027888
# STAT_CAUSE_DESCR_Powerline                 -0.000880              0.000714
# STAT_CAUSE_DESCR_Railroad                  -0.019300              0.004582
# STAT_CAUSE_DESCR_Smoking                    0.004611              0.004219
# STAT_CAUSE_DESCR_Structure                 -0.004881              0.005549
# REGION_None                                -0.027869             -0.024020
# REGION_Northeast                           -0.047840             -0.041231
# REGION_Northern Rockies                    -0.052654             -0.045380
# REGION_Northwest                           -0.045109             -0.038878
# REGION_Ohio Valley                         -0.072515             -0.062498
# REGION_South                               -0.147116             -0.126793
# REGION_Southeast                           -0.170557             -0.146996
# REGION_Southwest                            1.000000             -0.048432
# REGION_Upper Midwest                       -0.048432              1.000000
# REGION_West                                -0.059802             -0.051541
#
#                                     REGION_West
# OBJECTID                              -0.019815
# FOD_ID                                -0.009659
# FIRE_YEAR                             -0.038239
# DISCOVERY_DATE                        -0.032757
# DISCOVERY_DOY                          0.137981
# STAT_CAUSE_CODE                       -0.057271
# CONT_DATE                              0.010006
# CONT_DOY                               0.138278
# FIRE_SIZE                              0.018841
# LATITUDE                               0.096518
# LONGITUDE                             -0.510339
# OWNER_CODE                            -0.054779
# FIRE_SIZE_CLASS_BIN                    0.011991
# DAYS_TO_CONTAIN                        0.012443
# STAT_CAUSE_DESCR_Campfire             -0.004587
# STAT_CAUSE_DESCR_Children              0.005247
# STAT_CAUSE_DESCR_Debris Burning       -0.113927
# STAT_CAUSE_DESCR_Equipment Use         0.172874
# STAT_CAUSE_DESCR_Fireworks            -0.001648
# STAT_CAUSE_DESCR_Lightning             0.042466
# STAT_CAUSE_DESCR_Miscellaneous         0.083454
# STAT_CAUSE_DESCR_Missing/Undefined    -0.030157
# STAT_CAUSE_DESCR_Powerline             0.006735
# STAT_CAUSE_DESCR_Railroad             -0.026490
# STAT_CAUSE_DESCR_Smoking              -0.004306
# STAT_CAUSE_DESCR_Structure            -0.003673
# REGION_None                           -0.029658
# REGION_Northeast                      -0.050911
# REGION_Northern Rockies               -0.056034
# REGION_Northwest                      -0.048005
# REGION_Ohio Valley                    -0.077169
# REGION_South                          -0.156558
# REGION_Southeast                      -0.181505
# REGION_Southwest                      -0.059802
# REGION_Upper Midwest                  -0.051541
# REGION_West                            1.000000
#
# [36 rows x 36 columns]

# %%
fires.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 746709 entries, 13 to 1880463
# Data columns (total 34 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   OBJECTID                    746709 non-null  int64
#  1   FOD_ID                      746709 non-null  int64
#  2   FPA_ID                      746709 non-null  object
#  3   SOURCE_SYSTEM_TYPE          746709 non-null  object
#  4   SOURCE_SYSTEM               746709 non-null  object
#  5   NWCG_REPORTING_AGENCY       746709 non-null  object
#  6   NWCG_REPORTING_UNIT_ID      746709 non-null  object
#  7   NWCG_REPORTING_UNIT_NAME    746709 non-null  object
#  8   SOURCE_REPORTING_UNIT       746709 non-null  object
#  9   SOURCE_REPORTING_UNIT_NAME  746709 non-null  object
#  10  LOCAL_FIRE_REPORT_ID        118376 non-null  object
#  11  FIRE_NAME                   305330 non-null  object
#  12  FIRE_YEAR                   746709 non-null  int64
#  13  DISCOVERY_DATE              746709 non-null  float64
#  14  DISCOVERY_DOY               746709 non-null  int64
#  15  DISCOVERY_TIME              367546 non-null  object
#  16  STAT_CAUSE_CODE             746709 non-null  float64
#  17  STAT_CAUSE_DESCR            746709 non-null  object
#  18  CONT_DATE                   353510 non-null  float64
#  19  CONT_DOY                    353510 non-null  float64
#  20  CONT_TIME                   325419 non-null  object
#  21  FIRE_SIZE                   746709 non-null  float64
#  22  FIRE_SIZE_CLASS             746709 non-null  object
#  23  LATITUDE                    746709 non-null  float64
#  24  LONGITUDE                   746709 non-null  float64
#  25  OWNER_CODE                  746709 non-null  float64
#  26  OWNER_DESCR                 746709 non-null  object
#  27  STATE                       746709 non-null  object
#  28  Shape                       746709 non-null  object
#  29  FIRE_SIZE_CLASS_BIN         746709 non-null  int64
#  30  REGION                      746709 non-null  object
#  31  DAYS_TO_CONTAIN             746709 non-null  float64
#  32  DISCOVERY_DATE_DT           746709 non-null  datetime64[ns]
#  33  CONT_DATE_DT                353510 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(9), int64(5), object(18)
# memory usage: 199.4+ MB

# %%
from sklearn.model_selection import train_test_split

fires_train, fires_test = train_test_split(fires, test_size=0.2, random_state=42)

# %%
data_crosstab = pd.crosstab(fires_train['STAT_CAUSE_DESCR'], 
                            fires_train['FIRE_SIZE_CLASS_BIN'],  
                               margins = False, normalize = 'index') 
print(data_crosstab)
# Out:
# FIRE_SIZE_CLASS_BIN         0         1
# STAT_CAUSE_DESCR
# Arson                0.572871  0.427129
# Campfire             0.684866  0.315134
# Children             0.811753  0.188247
# Debris Burning       0.703270  0.296730
# Equipment Use        0.625239  0.374761
# Fireworks            0.582977  0.417023
# Lightning            0.499076  0.500924
# Miscellaneous        0.649920  0.350080
# Missing/Undefined    0.612341  0.387659
# Powerline            0.555556  0.444444
# Railroad             0.663299  0.336701
# Smoking              0.738477  0.261523
# Structure            0.707533  0.292467

# %%
# Box and whisker plot of fire size by cause

# %%
data_crosstab = pd.crosstab(fires_train['REGION'], 
                            fires_train['FIRE_SIZE_CLASS_BIN'],  
                               margins = False, normalize = 'index') 
print(data_crosstab)
# Out:
# FIRE_SIZE_CLASS_BIN         0         1
# REGION
# Alaska_Hawaii        0.390660  0.609340
# None                 0.726179  0.273821
# Northeast            0.902126  0.097874
# Northern Rockies     0.538987  0.461013
# Northwest            0.537150  0.462850
# Ohio Valley          0.540800  0.459200
# South                0.572376  0.427624
# Southeast            0.707106  0.292894
# Southwest            0.554888  0.445112
# Upper Midwest        0.695104  0.304896
# West                 0.609787  0.390213

# %%
# Box and whisker plot of fire size by region

# %%
#plt.scatter(data=fires_train, x='DAYS_TO_CONTAIN', y='FIRE_SIZE', marker='o', s=25);

# %%
combined_df = pd.get_dummies(fires_train, columns = ['STAT_CAUSE_DESCR', 'REGION'], drop_first = True)
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 597367 entries, 1071751 to 413409
# Data columns (total 54 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   OBJECTID                            597367 non-null  int64
#  1   FOD_ID                              597367 non-null  int64
#  2   FPA_ID                              597367 non-null  object
#  3   SOURCE_SYSTEM_TYPE                  597367 non-null  object
#  4   SOURCE_SYSTEM                       597367 non-null  object
#  5   NWCG_REPORTING_AGENCY               597367 non-null  object
#  6   NWCG_REPORTING_UNIT_ID              597367 non-null  object
#  7   NWCG_REPORTING_UNIT_NAME            597367 non-null  object
#  8   SOURCE_REPORTING_UNIT               597367 non-null  object
#  9   SOURCE_REPORTING_UNIT_NAME          597367 non-null  object
#  10  LOCAL_FIRE_REPORT_ID                94725 non-null   object
#  11  FIRE_NAME                           244403 non-null  object
#  12  FIRE_YEAR                           597367 non-null  int64
#  13  DISCOVERY_DATE                      597367 non-null  float64
#  14  DISCOVERY_DOY                       597367 non-null  int64
#  15  DISCOVERY_TIME                      294130 non-null  object
#  16  STAT_CAUSE_CODE                     597367 non-null  float64
#  17  CONT_DATE                           282664 non-null  float64
#  18  CONT_DOY                            282664 non-null  float64
#  19  CONT_TIME                           260338 non-null  object
#  20  FIRE_SIZE                           597367 non-null  float64
#  21  FIRE_SIZE_CLASS                     597367 non-null  object
#  22  LATITUDE                            597367 non-null  float64
#  23  LONGITUDE                           597367 non-null  float64
#  24  OWNER_CODE                          597367 non-null  float64
#  25  OWNER_DESCR                         597367 non-null  object
#  26  STATE                               597367 non-null  object
#  27  Shape                               597367 non-null  object
#  28  FIRE_SIZE_CLASS_BIN                 597367 non-null  int64
#  29  DAYS_TO_CONTAIN                     597367 non-null  float64
#  30  DISCOVERY_DATE_DT                   597367 non-null  datetime64[ns]
#  31  CONT_DATE_DT                        282664 non-null  datetime64[ns]
#  32  STAT_CAUSE_DESCR_Campfire           597367 non-null  uint8
#  33  STAT_CAUSE_DESCR_Children           597367 non-null  uint8
#  34  STAT_CAUSE_DESCR_Debris Burning     597367 non-null  uint8
#  35  STAT_CAUSE_DESCR_Equipment Use      597367 non-null  uint8
#  36  STAT_CAUSE_DESCR_Fireworks          597367 non-null  uint8
#  37  STAT_CAUSE_DESCR_Lightning          597367 non-null  uint8
#  38  STAT_CAUSE_DESCR_Miscellaneous      597367 non-null  uint8
#  39  STAT_CAUSE_DESCR_Missing/Undefined  597367 non-null  uint8
#  40  STAT_CAUSE_DESCR_Powerline          597367 non-null  uint8
#  41  STAT_CAUSE_DESCR_Railroad           597367 non-null  uint8
#  42  STAT_CAUSE_DESCR_Smoking            597367 non-null  uint8
#  43  STAT_CAUSE_DESCR_Structure          597367 non-null  uint8
#  44  REGION_None                         597367 non-null  uint8
#  45  REGION_Northeast                    597367 non-null  uint8
#  46  REGION_Northern Rockies             597367 non-null  uint8
#  47  REGION_Northwest                    597367 non-null  uint8
#  48  REGION_Ohio Valley                  597367 non-null  uint8
#  49  REGION_South                        597367 non-null  uint8
#  50  REGION_Southeast                    597367 non-null  uint8
#  51  REGION_Southwest                    597367 non-null  uint8
#  52  REGION_Upper Midwest                597367 non-null  uint8
#  53  REGION_West                         597367 non-null  uint8
# dtypes: datetime64[ns](2), float64(9), int64(5), object(16), uint8(22)
# memory usage: 162.9+ MB

# %% [markdown]
# ### Logistic Regression

# %%
# Since we're using more than one feature, let's scale our features
scaler = StandardScaler()
X_train = scaler.fit_transform(combined_df[['STAT_CAUSE_DESCR_Campfire', 
                    'STAT_CAUSE_DESCR_Children', 'STAT_CAUSE_DESCR_Debris Burning',
                     'STAT_CAUSE_DESCR_Equipment Use', 'STAT_CAUSE_DESCR_Fireworks',
                     'STAT_CAUSE_DESCR_Lightning', 'STAT_CAUSE_DESCR_Miscellaneous', 
                     'STAT_CAUSE_DESCR_Missing/Undefined', 'STAT_CAUSE_DESCR_Powerline',             
                     'STAT_CAUSE_DESCR_Railroad', 'STAT_CAUSE_DESCR_Smoking',
                      'STAT_CAUSE_DESCR_Structure']])
y_train = combined_df['FIRE_SIZE_CLASS_BIN']

# %%
lm_3 = LogisticRegression()
lm_3.fit(X_train, y_train)
lm_3.score(X_train, y_train)
# Out:
# 0.6328990386144531

# %%
combined_df_test = pd.get_dummies(fires_test, columns = ['STAT_CAUSE_DESCR', 'REGION'], drop_first = True)
combined_df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149342 entries, 824488 to 1310287
# Data columns (total 54 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   OBJECTID                            149342 non-null  int64
#  1   FOD_ID                              149342 non-null  int64
#  2   FPA_ID                              149342 non-null  object
#  3   SOURCE_SYSTEM_TYPE                  149342 non-null  object
#  4   SOURCE_SYSTEM                       149342 non-null  object
#  5   NWCG_REPORTING_AGENCY               149342 non-null  object
#  6   NWCG_REPORTING_UNIT_ID              149342 non-null  object
#  7   NWCG_REPORTING_UNIT_NAME            149342 non-null  object
#  8   SOURCE_REPORTING_UNIT               149342 non-null  object
#  9   SOURCE_REPORTING_UNIT_NAME          149342 non-null  object
#  10  LOCAL_FIRE_REPORT_ID                23651 non-null   object
#  11  FIRE_NAME                           60927 non-null   object
#  12  FIRE_YEAR                           149342 non-null  int64
#  13  DISCOVERY_DATE                      149342 non-null  float64
#  14  DISCOVERY_DOY                       149342 non-null  int64
#  15  DISCOVERY_TIME                      73416 non-null   object
#  16  STAT_CAUSE_CODE                     149342 non-null  float64
#  17  CONT_DATE                           70846 non-null   float64
#  18  CONT_DOY                            70846 non-null   float64
#  19  CONT_TIME                           65081 non-null   object
#  20  FIRE_SIZE                           149342 non-null  float64
#  21  FIRE_SIZE_CLASS                     149342 non-null  object
#  22  LATITUDE                            149342 non-null  float64
#  23  LONGITUDE                           149342 non-null  float64
#  24  OWNER_CODE                          149342 non-null  float64
#  25  OWNER_DESCR                         149342 non-null  object
#  26  STATE                               149342 non-null  object
#  27  Shape                               149342 non-null  object
#  28  FIRE_SIZE_CLASS_BIN                 149342 non-null  int64
#  29  DAYS_TO_CONTAIN                     149342 non-null  float64
#  30  DISCOVERY_DATE_DT                   149342 non-null  datetime64[ns]
#  31  CONT_DATE_DT                        70846 non-null   datetime64[ns]
#  32  STAT_CAUSE_DESCR_Campfire           149342 non-null  uint8
#  33  STAT_CAUSE_DESCR_Children           149342 non-null  uint8
#  34  STAT_CAUSE_DESCR_Debris Burning     149342 non-null  uint8
#  35  STAT_CAUSE_DESCR_Equipment Use      149342 non-null  uint8
#  36  STAT_CAUSE_DESCR_Fireworks          149342 non-null  uint8
#  37  STAT_CAUSE_DESCR_Lightning          149342 non-null  uint8
#  38  STAT_CAUSE_DESCR_Miscellaneous      149342 non-null  uint8
#  39  STAT_CAUSE_DESCR_Missing/Undefined  149342 non-null  uint8
#  40  STAT_CAUSE_DESCR_Powerline          149342 non-null  uint8
#  41  STAT_CAUSE_DESCR_Railroad           149342 non-null  uint8
#  42  STAT_CAUSE_DESCR_Smoking            149342 non-null  uint8
#  43  STAT_CAUSE_DESCR_Structure          149342 non-null  uint8
#  44  REGION_None                         149342 non-null  uint8
#  45  REGION_Northeast                    149342 non-null  uint8
#  46  REGION_Northern Rockies             149342 non-null  uint8
#  47  REGION_Northwest                    149342 non-null  uint8
#  48  REGION_Ohio Valley                  149342 non-null  uint8
#  49  REGION_South                        149342 non-null  uint8
#  50  REGION_Southeast                    149342 non-null  uint8
#  51  REGION_Southwest                    149342 non-null  uint8
#  52  REGION_Upper Midwest                149342 non-null  uint8
#  53  REGION_West                         149342 non-null  uint8
# dtypes: datetime64[ns](2), float64(9), int64(5), object(16), uint8(22)
# memory usage: 40.7+ MB

# %%
X_test = scaler.transform(combined_df_test[['STAT_CAUSE_DESCR_Campfire', 
                    'STAT_CAUSE_DESCR_Children', 'STAT_CAUSE_DESCR_Debris Burning',
                     'STAT_CAUSE_DESCR_Equipment Use', 'STAT_CAUSE_DESCR_Fireworks',
                     'STAT_CAUSE_DESCR_Lightning', 'STAT_CAUSE_DESCR_Miscellaneous', 
                     'STAT_CAUSE_DESCR_Missing/Undefined', 'STAT_CAUSE_DESCR_Powerline',             
                     'STAT_CAUSE_DESCR_Railroad', 'STAT_CAUSE_DESCR_Smoking',
                      'STAT_CAUSE_DESCR_Structure']])


preds = lm_3.predict(X_test)

conf_matrix = confusion_matrix(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
sns.heatmap(conf_matrix, cmap=plt.cm.Blues, annot=True, square=True, fmt='d')
plt.xlabel('prediction')
plt.ylabel('actual');

# %%
lm_3.score(X_test, combined_df_test['FIRE_SIZE_CLASS_BIN'])
# Out:
# 0.6338069665599765

# %%
f1_score(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
# Out:
# 0.22645619395173838

# %%
combined_df_test['FIRE_SIZE_CLASS_BIN'].value_counts()
# Out:
# 0    94585
# 1    54757
# Name: FIRE_SIZE_CLASS_BIN, dtype: int64

# %%
combined_df_test['proba_lrg'] = lm_3.predict_proba(combined_df_test[['STAT_CAUSE_DESCR_Campfire', 
                    'STAT_CAUSE_DESCR_Children', 'STAT_CAUSE_DESCR_Debris Burning',
                     'STAT_CAUSE_DESCR_Equipment Use', 'STAT_CAUSE_DESCR_Fireworks',
                     'STAT_CAUSE_DESCR_Lightning', 'STAT_CAUSE_DESCR_Miscellaneous', 
                     'STAT_CAUSE_DESCR_Missing/Undefined', 'STAT_CAUSE_DESCR_Powerline',             
                     'STAT_CAUSE_DESCR_Railroad', 'STAT_CAUSE_DESCR_Smoking',
                      'STAT_CAUSE_DESCR_Structure']])[:, 1]

fpr, tpr, thresholds = roc_curve(combined_df_test['FIRE_SIZE_CLASS_BIN'],
                                 combined_df_test['proba_lrg'])

def plot_roc(true, probas):
    auc = roc_auc_score(true, probas)

    plt.plot(fpr, tpr, marker='o')
    plt.xlabel('1 - Specificity (FPR)')
    plt.ylabel('Sensitivity (TPR)');
    plt.title(f"Area Under the ROC Curve: {round(auc, 3)}");

# %%
plot_roc(combined_df_test['FIRE_SIZE_CLASS_BIN'], lm_3.predict_proba(X_test)[:, 1])

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(combined_df[['REGION_None', 
                    'REGION_Northeast', 'REGION_Northern Rockies',
                     'REGION_Northwest', 'REGION_Ohio Valley',
                     'REGION_South', 'REGION_Southeast', 
                     'REGION_Southwest', 'REGION_Upper Midwest',             
                     'REGION_West']])
y_train = combined_df['FIRE_SIZE_CLASS_BIN']

# %%
lm_4 = LogisticRegression()
lm_4.fit(X_train, y_train)
lm_4.score(X_train, y_train)
# Out:
# 0.634330319552302

# %%
X_test = scaler.transform(combined_df_test[[ 'REGION_None', 
                    'REGION_Northeast', 'REGION_Northern Rockies',
                     'REGION_Northwest', 'REGION_Ohio Valley',
                     'REGION_South', 'REGION_Southeast', 
                     'REGION_Southwest', 'REGION_Upper Midwest',             
                     'REGION_West']])


preds = lm_4.predict(X_test)

conf_matrix = confusion_matrix(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
sns.heatmap(conf_matrix, cmap=plt.cm.Blues, annot=True, square=True, fmt='d')
plt.xlabel('prediction')
plt.ylabel('actual');

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(combined_df[['REGION_None', 
                    'REGION_Northeast', 'REGION_Northern Rockies',
                     'REGION_Northwest', 'REGION_Ohio Valley',
                     'REGION_South', 'REGION_Southeast', 
                     'REGION_Southwest', 'REGION_Upper Midwest',             
                     'REGION_West', 'STAT_CAUSE_DESCR_Campfire', 
                    'STAT_CAUSE_DESCR_Children', 'STAT_CAUSE_DESCR_Debris Burning',
                     'STAT_CAUSE_DESCR_Equipment Use', 'STAT_CAUSE_DESCR_Fireworks',
                     'STAT_CAUSE_DESCR_Lightning', 'STAT_CAUSE_DESCR_Miscellaneous', 
                     'STAT_CAUSE_DESCR_Missing/Undefined', 'STAT_CAUSE_DESCR_Powerline',             
                     'STAT_CAUSE_DESCR_Railroad', 'STAT_CAUSE_DESCR_Smoking',
                      'STAT_CAUSE_DESCR_Structure']])
y_train = combined_df['FIRE_SIZE_CLASS_BIN']

# %%
lm_5 = LogisticRegressionCV()
lm_5.fit(X_train, y_train)
lm_5.score(X_train, y_train)
# Out:
# 0.6383496242678287

# %%
X_test = scaler.transform(combined_df_test[[ 'REGION_None', 
                    'REGION_Northeast', 'REGION_Northern Rockies',
                     'REGION_Northwest', 'REGION_Ohio Valley',
                     'REGION_South', 'REGION_Southeast', 
                     'REGION_Southwest', 'REGION_Upper Midwest',             
                     'REGION_West', 'STAT_CAUSE_DESCR_Campfire', 
                    'STAT_CAUSE_DESCR_Children', 'STAT_CAUSE_DESCR_Debris Burning',
                     'STAT_CAUSE_DESCR_Equipment Use', 'STAT_CAUSE_DESCR_Fireworks',
                     'STAT_CAUSE_DESCR_Lightning', 'STAT_CAUSE_DESCR_Miscellaneous', 
                     'STAT_CAUSE_DESCR_Missing/Undefined', 'STAT_CAUSE_DESCR_Powerline',             
                     'STAT_CAUSE_DESCR_Railroad', 'STAT_CAUSE_DESCR_Smoking',
                      'STAT_CAUSE_DESCR_Structure']])


preds = lm_5.predict(X_test)

conf_matrix = confusion_matrix(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
sns.heatmap(conf_matrix, cmap=plt.cm.Blues, annot=True, square=True, fmt='d')
plt.xlabel('prediction')
plt.ylabel('actual');

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.model_selection import cross_val_score

X_train = combined_df[['STAT_CAUSE_DESCR_Campfire', 
                    'STAT_CAUSE_DESCR_Children', 'STAT_CAUSE_DESCR_Debris Burning',
                     'STAT_CAUSE_DESCR_Equipment Use', 'STAT_CAUSE_DESCR_Fireworks',
                     'STAT_CAUSE_DESCR_Lightning', 'STAT_CAUSE_DESCR_Miscellaneous', 
                     'STAT_CAUSE_DESCR_Missing/Undefined', 'STAT_CAUSE_DESCR_Powerline',             
                     'STAT_CAUSE_DESCR_Railroad', 'STAT_CAUSE_DESCR_Smoking',
                      'STAT_CAUSE_DESCR_Structure']]

y_train = combined_df['FIRE_SIZE_CLASS_BIN']


knn = KNeighborsClassifier(n_neighbors=5)
scores = cross_val_score(knn, X_train, y_train, cv=10, scoring='accuracy')
print(scores)

# %%
knn = KNeighborsClassifier(n_neighbors=3)
scores = cross_val_score(knn, X_train, y_train, cv=10, scoring='accuracy')
print(scores)

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import BernoulliNB, MultinomialNB, GaussianNB
# either Bernoulli or Multinomial
nb = NB()
nb.fit(X_train, y_train)
nb.score(X_train, y_train)

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import train_test_split

def quick_test(model, X, y):
    xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.3)
    model.fit(xtrain, ytrain)
    return model.score(xtest, ytest)

def quick_test_afew_times(model, X, y, n=10):
    return np.mean([quick_test(model, X, y) for j in range(n)])

# %%
X_train = combined_df[['REGION_None', 
                    'REGION_Northeast', 'REGION_Northern Rockies',
                     'REGION_Northwest', 'REGION_Ohio Valley',
                     'REGION_South', 'REGION_Southeast', 
                     'REGION_Southwest', 'REGION_Upper Midwest',             
                     'REGION_West', 'STAT_CAUSE_DESCR_Campfire', 
                    'STAT_CAUSE_DESCR_Children', 'STAT_CAUSE_DESCR_Debris Burning',
                     'STAT_CAUSE_DESCR_Equipment Use', 'STAT_CAUSE_DESCR_Fireworks',
                     'STAT_CAUSE_DESCR_Lightning', 'STAT_CAUSE_DESCR_Miscellaneous', 
                     'STAT_CAUSE_DESCR_Missing/Undefined', 'STAT_CAUSE_DESCR_Powerline',             
                     'STAT_CAUSE_DESCR_Railroad', 'STAT_CAUSE_DESCR_Smoking',
                      'STAT_CAUSE_DESCR_Structure', 'DISCOVERY_DOY', 'FIRE_YEAR']]

y_train = combined_df['FIRE_SIZE_CLASS_BIN']

# %%
randomforest = RandomForestClassifier(n_estimators=100)
quick_test_afew_times(randomforest, X_train, y_train)
# Out:
# 0.616428679043139

# %%
X_test = (combined_df_test[[ 'REGION_None', 
                    'REGION_Northeast', 'REGION_Northern Rockies',
                     'REGION_Northwest', 'REGION_Ohio Valley',
                     'REGION_South', 'REGION_Southeast', 
                     'REGION_Southwest', 'REGION_Upper Midwest',             
                     'REGION_West', 'STAT_CAUSE_DESCR_Campfire', 
                    'STAT_CAUSE_DESCR_Children', 'STAT_CAUSE_DESCR_Debris Burning',
                     'STAT_CAUSE_DESCR_Equipment Use', 'STAT_CAUSE_DESCR_Fireworks',
                     'STAT_CAUSE_DESCR_Lightning', 'STAT_CAUSE_DESCR_Miscellaneous', 
                     'STAT_CAUSE_DESCR_Missing/Undefined', 'STAT_CAUSE_DESCR_Powerline',             
                     'STAT_CAUSE_DESCR_Railroad', 'STAT_CAUSE_DESCR_Smoking',
                      'STAT_CAUSE_DESCR_Structure', 'DISCOVERY_DOY', 'FIRE_YEAR']])


preds = randomforest.predict(X_test)

# %%
conf_matrix = confusion_matrix(combined_df_test['FIRE_SIZE_CLASS_BIN'], preds)
sns.heatmap(conf_matrix, cmap=plt.cm.Blues, annot=True, square=True, fmt='d')
plt.xlabel('prediction')
plt.ylabel('actual');

# %%
def visualize(X, y, bdry='diag'):
    c = cm.rainbow(np.linspace(0, 1, 2))
    plt.scatter([i[0] for i in X], [i[1] for i in X], color=[c[i] for i in y], alpha=.5)
    
    #Plot the true decision boundary
    if bdry == 'diag':
        plt.plot([0, 1], [0, 1], 'k--')
    elif bdry == 'quadrant':
        plt.plot([0, 1], [0.5, 0.5], 'k--')
        plt.plot([0.5, 0.5], [0, 1], 'k--')
        
    plt.grid(True)

# %%
randomforest.fit(X_train, y_train)

grid = np.mgrid[0:1.02:0.02, 0:1.02:0.02].reshape(2,-1).T
visualize(grid, randomforest.predict(grid))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-5ccfcf0ee797> in <module>
#       2
#       3 grid = np.mgrid[0:1.02:0.02, 0:1.02:0.02].reshape(2,-1).T
# ----> 4 visualize(grid, randomforest.predict(grid))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     627             The predicted classes.
#     628         """
# --> 629         proba = self.predict_proba(X)
#     630
#     631         if self.n_outputs_ == 1:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in predict_proba(self, X)
#     671         check_is_fitted(self)
#     672         # Check data
# --> 673         X = self._validate_X_predict(X)
#     674
#     675         # Assign chunk of trees to jobs
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in _validate_X_predict(self, X)
#     419         check_is_fitted(self)
#     420
# --> 421         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     422
#     423     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in _validate_X_predict(self, X, check_input)
#     394         n_features = X.shape[1]
#     395         if self.n_features_ != n_features:
# --> 396             raise ValueError("Number of features of the model must "
#     397                              "match the input. Model n_features is %s and "
#     398                              "input n_features is %s "
#
# ValueError: Number of features of the model must match the input. Model n_features is 24 and input n_features is 2

# %%
# Need to do
# Precision Recall Curve
# Correlation
